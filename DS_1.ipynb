# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
import seaborn as sns 
import matplotlib.pyplot as plt 
train = pd.read_csv("train.csv", sep=';', decimal=",")
test = pd.read_csv("test.csv", sep=';', decimal=",")
regr = LinearRegression()
X_train = train[['X1','X2']]
y_train = train[['Y']]
X_test = test[['X1','X2']]
y_test = test[['Y']]
regr.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
regr.score(X_train, y_train)
# Out:
# 0.6094643037018033

# %%
regr.score(X_test, y_test)
# Out:
# 0.5995177394697264

# %%
y_pred = regr.predict(X_test)

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(train[['X1']], train[['X2']], y_train, marker='o')

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(test[['X1']], test[['X2']], y_pred, marker='o')

# %%
from sklearn import tree
clf = tree.DecisionTreeRegressor(max_depth = 3)
clf = clf.fit(X_train, y_train)
y_pred_clf = clf.predict(X_test)
clf.score(X_train, y_train)
# Out:
# 0.716188156850741

# %%
clf.score(X_test, y_test)
# Out:
# 0.6808318482767197

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(test[['X1']], test[['X2']], y_pred_clf, marker='o')
